# %% [markdown]
# <a href="https://colab.research.google.com/github/thyeaditungson29/mystudy_ADL2022/blob/main/UAS_ADL_NucleiSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **UAS Applied Deep Learning**
#
# Project: XNet: Deep Adversarial Training for Multi-Organ Nuclei
# Segmentation in Histopathology Images
#
# Paper: https://paperswithcode.com/paper/deep-adversarial-training-for-multi-organ#code
#
# Code Source Github: https://github.com/mahmoodlab/NucleiSegmentation
#
# Data: https://www.kaggle.com/datasets/tuanledinh/processedoriginalmonuseg

# %% [markdown]
# # **Pre-Request**
#
# **Menghubungkan ke github**

# %%
# !git clone https://github.com/thyeaditungson29/mystudy_ADL2022.git
# Out:
# Cloning into 'mystudy_ADL2022'...
# remote: Enumerating objects: 547, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 547 (delta 92), reused 154 (delta 56), pack-reused 273
# Receiving objects: 100% (547/547), 364.60 MiB | 39.73 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# Checking out files: 100% (222/222), done.

# %% [markdown]
# # **Install Paket yang dibutuhkan**

# %%
# !pip install -q dominate
# !pip install -q scipy==1.1.0
# !pip install -q pytorch torchvision cudatoolkit==10.1 
# !pip install -q visdom
# Out:
#      |████████████████████████████████| 31.2 MB 1.2 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# jax 0.3.8 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ERROR: Could not find a version that satisfies the requirement cudatoolkit==10.1 (from versions: none)
# ERROR: No matching distribution found for cudatoolkit==10.1
#      |████████████████████████████████| 676 kB 5.4 MB/s
#      |████████████████████████████████| 54 kB 3.3 MB/s
# ...

# %%
#Pilihan running ke CPU jika GPU tidak tersedia
import torch
torch.device('cuda' if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cuda')

# %% [markdown]
# # **Memilih Root Folder**

# %%
# %cd /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation
# Out:
# /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation

# %%
#menghapus file cache yang ada
# !find . -name \*.pyc -delete

# %% [markdown]
# # **Menjalankan Proses Train**

# %%
# !python train.py --dataroot /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/datasets/Nuclei_Segmentation --name NU_SEG  --gpu_ids 0 --display_id 0 --lambda_L1 70 --niter 200 --niter_decay 200 --pool_size 64 --loadSize 256 --fineSize 256
# Out:
# ----------------- Options ---------------
#                 batchSize: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/datasets/Nuclei_Segmentation	[default: None]
#              dataset_mode: aligned
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#               epoch_count: 1
#                  fineSize: 256
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 70.0                          	[default: 100.0]
# ...

# %% [markdown]
# # **Menjalankan Proses Test**

# %%
# !python test.py --dataroot /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/datasets/Nuclei_Segmentation --name NU_SEG --gpu_ids 0 --display_id 0 --loadSize 256 --fineSize 256
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                 batchSize: 1
#           checkpoints_dir: ./checkpoints
#                  dataroot: /content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/datasets/Nuclei_Segmentation	[default: None]
#              dataset_mode: single
#                display_id: 0                             	[default: 1]
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                  fineSize: 256
#                   gpu_ids: 0
#                  how_many: 50
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                  loadSize: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                  nThreads: 4
#                n_layers_D: 3
# ...

# %% [markdown]
# # **Mengcopy hasil pekerjaan ke google drive**

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
#Folder SUMBER dan Folder Sumber silahkan diatur
# !cp -av "/content/mystudy_ADL2022/UAS_ADL" "/content/gdrive/MyDrive"
# Out:
# '/content/mystudy_ADL2022/UAS_ADL' -> '/content/gdrive/MyDrive/UAS_ADL'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/README.md' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation/README.md'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/data' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation/data'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/data/__init__.py' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation/data/__init__.py'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/data/aligned_dataset.py' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation/data/aligned_dataset.py'
# '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/data/base_data_loader.py' -> '/content/gdrive/MyDrive/UAS_ADL/NucleiSegmentation/data/base_data_loader.py'
# ...

# %% [markdown]
# # **Menampilkan Hasil Gambar dari CGAN**
#
# **Gambar Fake Image dan Real Image dari gambar 0001**

# %%
import numpy as np
import PIL
from IPython.display import display

path1 = '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/results/NU_SEG/test_latest/images/'


list_im = [path1+"0001_fake_B.png", path1+"0001_real_A.png"]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#imgs_comb.save( 'combo.jpg' )    

display(imgs_comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F8F1899F6D0>

# %% [markdown]
# **Gambar Fake Image dan Real Image dari gambar 0019**

# %%
list_im = [path1+"0019_fake_B.png", path1+"0019_real_A.png"]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#imgs_comb.save( 'combo.jpg' )    

display(imgs_comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F8F1890DDD0>

# %% [markdown]
# **Gambar Fake Image_B dari epoch 300, 325, 350, dan 400**

# %%
path2 = '/content/mystudy_ADL2022/UAS_ADL/NucleiSegmentation/checkpoints/NU_SEG/web/images/'

list_im = [path2+"epoch300_fake_B.png", path2+"epoch325_fake_B.png", path2+"epoch350_fake_B.png", path2+"epoch400_fake_B.png"]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#imgs_comb.save( 'combo.jpg' )    

display(imgs_comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   import sys
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F8F189BEC90>

# %% [markdown]
# **Gambar Real Image_A dari epoch 300, 325, 350, dan 400**

# %%
list_im = [path2+"epoch300_real_A.png", path2+"epoch325_real_A.png", path2+"epoch350_real_A.png", path2+"epoch400_real_A.png"]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#imgs_comb.save( 'combo.jpg' )    

display(imgs_comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F8F18918E90>

# %% [markdown]
# **Gambar Real Image_B dari epoch 300, 325, 350, dan 400**

# %%
list_im = [path2+"epoch300_real_B.png", path2+"epoch325_real_B.png", path2+"epoch350_real_B.png", path2+"epoch400_real_B.png"]
imgs    = [ PIL.Image.open(i) for i in list_im ]
# pick the image which is the smallest, and resize the others to match it (can be arbitrary image shape here)
min_shape = sorted( [(np.sum(i.size), i.size ) for i in imgs])[0][1]
imgs_comb = np.hstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )

# save that beautiful picture
imgs_comb = PIL.Image.fromarray( imgs_comb)
#imgs_comb.save( 'combo.jpg' )    

display(imgs_comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """
# <PIL.Image.Image image mode=RGB size=1024x256 at 0x7F8F189BE150>
